# %% [markdown]
# # Intent Classification

# %%
import sys, os
from pathlib import Path
from openai import OpenAI
from dotenv import load_dotenv

sys.path.insert(0, str(Path(os.getcwd()).parent))
from src.intent_classifer import classify_intent

# %%
load_dotenv()
# Out:
# True

# %%
client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url="https://openrouter.ai/api/v1"
)

# %%
model_name="openai/gpt-oss-20b"

# %%
classify_intent(client, model_name, user_message="I keep overthinking everything")
# Out:
# 'asking_mental_health_question'

# %%
classify_intent(client, model_name, user_message="Hello! How are you?")
# Out:
# 'greeting'

# %%
classify_intent(client, model_name, user_message="See you again, Bye!")
# Out:
# 'goodbye'

# %%
classify_intent(client, model_name, user_message="I feeling so good today")
# Out:
# 'out_of_scope'
